# %%
import pandas as pd
from pprint import pprint as pprint

def read_prefixes(filename):
    """ 
    :param filename: path to a CSV file with columns "ns", "uri"
    :return: 
    """
    return pd.read_csv(filename, header=0, names=["ns", "uri"])

def read_fp_distinct(filename):
    """ 
    :param filename: path to a CSV file with columns "s", "p", "o"
    :return: 
    """
    return pd.read_csv(filename, header=0, names=["s", "p", "o"])

def read_fp_count(filename):
    """ 
    :param filename: path to a CSV file with columns "s", "p", "o", "c"
    :return: 
    """
    return pd.read_csv(filename, header=0, names=["s", "p", "o", "c"])

def replace_ns(triples, ns_dataframe):
    """ 
    :param triples: a dataframe with columns (s,p,o)
    :param ns_dataframe: a dataframe with columns (ns,uri)
    :return: triples replaced with ns
    """
    d = dict(zip(ns_dataframe.uri, ns_dataframe.ns))
    return triples.replace(d, regex=True)

def df_to_set_of_tuples(df, list_of_desired_columns=["s", "p", "o"]):
    """ 
    :param df: the fingerprint dataframe 
    :param list_of_desired_columns: in case it is a fingerprint with counts then this is an option 
            to remove the count column, or select any combination of columns
    :return: set of tuples
    """
    return set([tuple(line) for line in df[list_of_desired_columns].values.tolist()])

def df_diff(alpha, beta):
    """ 
    provides the set difference between two dataframes
    :param alpha: first dataframe
    :param beta: second dataframe
    :return: (a^b, a - b, b - a)
    """
    a = df_to_set_of_tuples(alpha)
    b = df_to_set_of_tuples(beta)
    return a.intersection(b), a.difference(b), b.difference(a)


fp1 = read_fp_count("test/dataset_figerprint_for_count.rq_eurovoc44.log")
fp2 = read_fp_count("test/dataset_figerprint_for_count.rq_EV45OLD.log")
ns = read_prefixes("test/prefix.csv")

fp1 = replace_ns(fp1,ns)
fp2 = replace_ns(fp2,ns)

print "Done."
# Out:
# Done.

# %% [markdown]
# The next section defines functions generating parts of latex documents

# %%
from pylatex import Package
from pylatex import Section, Subsection, Document
from pylatex.base_classes import Environment
from pylatex.utils import NoEscape


class LandscapeEnvironment(Environment):
    _latex_name = 'landscape'
    packages = [Package('pdflscape')]

def diff_to_latex_section(tex_doc, alpha, alpha_description, beta, beta_description,
                          cols=["Subject", "Predicate", "Object"]):
    """ 
    :param tex_doc: the pylatex document
    :param alpha: the first fingerprint
    :param alpha_description: the first fingerprint description
    :param beta: the second fingerprint
    :param beta_description: the second fingerprint description
    :return: returns a section of latex document with deltas
    """
    cmn_s, adb_s, bda_s = df_diff(alpha, beta)

    cmn_df = pd.DataFrame(list(cmn_s), columns=cols, )
    cmn_df.sort_values(by=cols, inplace=True)

    adb_df = pd.DataFrame(list(adb_s), columns=cols, )
    adb_df.sort_values(by=cols, inplace=True)

    bda_df = pd.DataFrame(list(bda_s), columns=cols, )
    bda_df.sort_values(by=cols, inplace=True)

    ref_alpha = alpha_description["title"]
    ref_beta = beta_description["title"]

    section_title = 'Difference between ' + ref_alpha + ' and ' + ref_beta
    with tex_doc.create(LandscapeEnvironment()):
        with tex_doc.create(Section(section_title)):
            # tex_doc.append(alpha_description)
            # tex_doc.append(beta_description)
            with tex_doc.create(Subsection("Common parts")) as subsec:
                subsec.append("The table below represents the elements common to both datasets.")
                # with tex_doc.create(Table(position='H')) as tbl:
                tex_doc.append(NoEscape(cmn_df.to_latex(longtable=True, index=False)))

            with tex_doc.create(Subsection("Unique to " + ref_alpha)) as subsec:
                subsec.append(
                    "The table below represents the elements present in " + ref_alpha + " but missing in " + ref_beta + ".")
                # with tex_doc.create(Table(position='H')) as tbl:
                tex_doc.append(NoEscape(adb_df.to_latex(longtable=True, index=False)))

            with tex_doc.create(Subsection("Unique to " + ref_beta)) as subsec:
                subsec.append(
                    "The table below represents the elements present in " + ref_beta + " but missing in " + ref_alpha + ".")
                # with tex_doc.create(Table(position='H')) as tbl:
                tex_doc.append(NoEscape(bda_df.to_latex(longtable=True, index=False)))

                # diff_to_latex_table(fp1, "Bla Bla", fp2, "Blu blu")


configuration_dict = {
    "type": "difference between two dataset fingerprints",
    "alpha": {"title": "EuroVoc 4.4",
              "filename": "test/dataset_figerprint_for_count.rq_eurovoc44.log",
              "desc": "EuroVoc 4.4 was released a long time ago using EuroVoc Ontology"},
    "beta": {"title": "EuroVoc 4.5",
             "filename": "test/dataset_figerprint_for_count.rq_EV45OLD.log",
             "desc": "EuroVoc 4.5 was released in July 2016 with SKOS-AP-EU and then converted to fit also the old EuroVoc Ontology."},
}

def generate_document(filename, config=configuration_dict):
    """ 
    :param filename: filename for the tex document
    :param config: 
    :return: None
    """
    geometry_options = {
        "head": "40pt",
        "margin": "0.5in",
        "bottom": "0.6in",
        "includeheadfoot": True
    }
    doc = Document('basic', geometry_options=geometry_options)
    
    doc.packages.append(Package('longtable'))
    doc.packages.append(Package('booktabs'))
    doc.packages.append(Package('float'))
    doc.packages.append(Package('ltablex'))
    doc.packages.append(Package('pdflscape'))
    
    first_page = PageStyle("firstpage")
    
    
    # Add document title
    with first_page.create(Head("R")) as right_header:
        with right_header.create(MiniPage(width=NoEscape(r"0.49\textwidth"),
                                 pos='c', align='r')) as title_wrapper:
            title_wrapper.append(LargeText(bold("Bank Account Statement")))
            title_wrapper.append(LineBreak())
            title_wrapper.append(MediumText(bold("Date")))

    # Add footer
    with first_page.create(Foot("C")) as footer:
        message = "Important message please read"
        with footer.create(Tabularx(
                "X X X X",
                width_argument=NoEscape(r"\textwidth"))) as footer_table:

            footer_table.add_row(
                [MultiColumn(4, align='l', data=TextColor("blue", message))])
            footer_table.add_hline(color="blue")
            footer_table.add_empty_row()

            branch_address = MiniPage(
                width=NoEscape(r"0.25\textwidth"),
                pos='t')
            branch_address.append("960 - 22nd street east")
            branch_address.append("\n")
            branch_address.append("Saskatoon, SK")

            document_details = MiniPage(width=NoEscape(r"0.25\textwidth"),
                                        pos='t', align='r')
            document_details.append("1000")
            document_details.append(LineBreak())
            document_details.append(simple_page_number())

            footer_table.add_row([branch_address, branch_address,
                                  branch_address, document_details])

    doc.preamble.append(first_page)
    # End first page style
    


    diff_to_latex_section(doc, fp1, config["alpha"], fp2, config["beta"])
    doc.generate_tex(filepath=filename)
    doc.generate_pdf(clean_tex=False, filepath=filename)

generate_document("temp/diff_report", configuration_dict)

# %% [markdown]
# the next section generates the LaTex documents and compiles them to PDF

# %%
from df_io import read_prefixes, read_fp_spo_count, replace_ns, compile_tex_file_multipass
ns = read

read_fp_spo_count("test/test_fingerprint_spo.csv").replace_ns()
# Out:
#                                                  stype  \
# 0    http://publications.europa.eu/ontology/authori...
# 1    http://publications.europa.eu/ontology/authori...
# 2    http://publications.europa.eu/ontology/authori...
# 3    http://publications.europa.eu/ontology/authori...
# 4    http://publications.europa.eu/ontology/euvoc#C...
# 5    http://publications.europa.eu/ontology/euvoc#C...
# 6    http://publications.europa.eu/ontology/euvoc#C...
# 7    http://publications.europa.eu/ontology/euvoc#C...
# 8    http://publications.europa.eu/ontology/euvoc#C...
# 9    http://publications.europa.eu/ontology/euvoc#C...
# 10   http://publications.europa.eu/ontology/euvoc#C...
# 11   http://publications.europa.eu/ontology/euvoc#C...
# 12   http://publications.europa.eu/ontology/euvoc#C...
# 13   http://publications.europa.eu/ontology/euvoc#C...
# 14   http://publications.europa.eu/ontology/euvoc#C...
# 15   http://publications.europa.eu/ontology/euvoc#C...
# 16   http://publications.europa.eu/ontology/euvoc#C...
# 17   http://publications.europa.eu/ontology/euvoc#C...
# 18   http://publications.europa.eu/ontology/euvoc#C...
# 19   http://publications.europa.eu/ontology/euvoc#C...
# 20   http://publications.europa.eu/ontology/euvoc#C...
# 21   http://publications.europa.eu/ontology/euvoc#C...
# 22   http://publications.europa.eu/ontology/euvoc#C...
# 23   http://publications.europa.eu/ontology/euvoc#L...
# 24   http://publications.europa.eu/ontology/euvoc#L...
# 25   http://publications.europa.eu/ontology/euvoc#L...
# 26   http://publications.europa.eu/ontology/euvoc#L...
# 27   http://publications.europa.eu/ontology/euvoc#L...
# 28   http://publications.europa.eu/ontology/euvoc#L...
# 29   http://publications.europa.eu/ontology/euvoc#L...
# ..                                                 ...
# 290                    http://xmlns.com/foaf/0.1/Agent
# 291                    http://xmlns.com/foaf/0.1/Agent
# 292                    http://xmlns.com/foaf/0.1/Agent
# 293                    http://xmlns.com/foaf/0.1/Agent
# 294                    http://xmlns.com/foaf/0.1/Agent
# 295                    http://xmlns.com/foaf/0.1/Agent
# 296                    http://xmlns.com/foaf/0.1/Agent
# 297                    http://xmlns.com/foaf/0.1/Agent
# 298                    http://xmlns.com/foaf/0.1/Agent
# 299                    http://xmlns.com/foaf/0.1/Agent
# 300                    http://xmlns.com/foaf/0.1/Agent
# 301                    http://xmlns.com/foaf/0.1/Agent
# 302                    http://xmlns.com/foaf/0.1/Agent
# 303                    http://xmlns.com/foaf/0.1/Agent
# 304                    http://xmlns.com/foaf/0.1/Agent
# 305                    http://xmlns.com/foaf/0.1/Agent
# 306                    http://xmlns.com/foaf/0.1/Agent
# 307                    http://xmlns.com/foaf/0.1/Agent
# 308                    http://xmlns.com/foaf/0.1/Agent
# 309                    http://xmlns.com/foaf/0.1/Agent
# 310                    http://xmlns.com/foaf/0.1/Agent
# 311                    http://xmlns.com/foaf/0.1/Agent
# 312                    http://xmlns.com/foaf/0.1/Agent
# 313                    http://xmlns.com/foaf/0.1/Agent
# 314                    http://xmlns.com/foaf/0.1/Agent
# 315                    http://xmlns.com/foaf/0.1/Agent
# 316                    http://xmlns.com/foaf/0.1/Agent
# 317                    http://xmlns.com/foaf/0.1/Agent
# 318                    http://xmlns.com/foaf/0.1/Agent
# 319                    http://xmlns.com/foaf/0.1/Agent
#
#                                                      p  \
# 0    http://publications.europa.eu/ontology/authori...
# 1    http://publications.europa.eu/ontology/authori...
# 2               http://purl.org/dc/elements/1.1/source
# 3      http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4    http://publications.europa.eu/ontology/authori...
# 5    http://publications.europa.eu/ontology/authori...
# 6    http://publications.europa.eu/ontology/euvoc#s...
# 7    http://publications.europa.eu/ontology/euvoc#s...
# 8    http://publications.europa.eu/ontology/euvoc#s...
# 9    http://publications.europa.eu/ontology/euvoc#x...
# 10   http://publications.europa.eu/resource/authori...
# 11                    http://purl.org/dc/terms/created
# 12               http://purl.org/dc/terms/dateAccepted
# 13              http://purl.org/dc/terms/dateSubmitted
# 14     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 15           http://www.w3.org/2002/07/owl#versionInfo
# 16      http://www.w3.org/2004/02/skos/core#definition
# 17        http://www.w3.org/2004/02/skos/core#inScheme
# 18        http://www.w3.org/2004/02/skos/core#inScheme
# 19       http://www.w3.org/2004/02/skos/core#prefLabel
# 20    http://www.w3.org/2004/02/skos/core#topConceptOf
# 21    http://www.w3.org/2004/02/skos/core#topConceptOf
# 22         http://www.w3.org/2008/05/skos-xl#prefLabel
# 23   http://publications.europa.eu/ontology/authori...
# 24   http://publications.europa.eu/ontology/authori...
# 25   http://publications.europa.eu/ontology/euvoc#s...
# 26   http://publications.europa.eu/ontology/euvoc#s...
# 27   http://publications.europa.eu/ontology/euvoc#s...
# 28   http://publications.europa.eu/resource/authori...
# 29                    http://purl.org/dc/terms/created
# ..                                                 ...
# 290    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 291          http://www.w3.org/2002/07/owl#versionInfo
# 292   http://www.w3.org/2003/01/geo/wgs84_pos#location
# 293        http://www.w3.org/2004/02/skos/core#broader
# 294        http://www.w3.org/2004/02/skos/core#broader
# 295        http://www.w3.org/2004/02/skos/core#broader
# 296        http://www.w3.org/2004/02/skos/core#broader
# 297     http://www.w3.org/2004/02/skos/core#changeNote
# 298     http://www.w3.org/2004/02/skos/core#definition
# 299     http://www.w3.org/2004/02/skos/core#exactMatch
# 300    http://www.w3.org/2004/02/skos/core#historyNote
# 301       http://www.w3.org/2004/02/skos/core#inScheme
# 302       http://www.w3.org/2004/02/skos/core#inScheme
# 303   http://www.w3.org/2004/02/skos/core#newPropoerty
# 304       http://www.w3.org/2004/02/skos/core#notation
# 305       http://www.w3.org/2004/02/skos/core#notation
# 306       http://www.w3.org/2004/02/skos/core#notation
# 307       http://www.w3.org/2004/02/skos/core#notation
# 308       http://www.w3.org/2004/02/skos/core#notation
# 309       http://www.w3.org/2004/02/skos/core#notation
# 310       http://www.w3.org/2004/02/skos/core#notation
# 311       http://www.w3.org/2004/02/skos/core#notation
# 312       http://www.w3.org/2004/02/skos/core#notation
# 313       http://www.w3.org/2004/02/skos/core#notation
# 314       http://www.w3.org/2004/02/skos/core#notation
# 315      http://www.w3.org/2004/02/skos/core#prefLabel
# 316   http://www.w3.org/2004/02/skos/core#topConceptOf
# 317   http://www.w3.org/2004/02/skos/core#topConceptOf
# 318         http://www.w3.org/2008/05/skos-xl#altLabel
# 319        http://www.w3.org/2008/05/skos-xl#prefLabel
#
#                                                 ootype propType  scnt   ocnt  \
# 0              http://www.w3.org/2001/XMLSchema#string     data  1053      7
# 1              http://www.w3.org/2001/XMLSchema#string     data  1340   1116
# 2              http://www.w3.org/2001/XMLSchema#string     data  1340      7
# 3    http://publications.europa.eu/ontology/authori...   object  1340      1
# 4              http://www.w3.org/2001/XMLSchema#string     data     9      9
# 5              http://www.w3.org/2001/XMLSchema#string     data     9      9
# 6                http://www.w3.org/2001/XMLSchema#date     data     9      3
# 7    http://publications.europa.eu/ontology/euvoc#C...   object     9      1
# 8          http://www.w3.org/2004/02/skos/core#Concept   object     9      1
# 9    http://publications.europa.eu/ontology/euvoc#X...   object     9     18
# 10             http://www.w3.org/2001/XMLSchema#string     data     9      9
# 11               http://www.w3.org/2001/XMLSchema#date     data     9      4
# 12               http://www.w3.org/2001/XMLSchema#date     data     4      1
# 13               http://www.w3.org/2001/XMLSchema#date     data     4      1
# 14   http://publications.europa.eu/ontology/euvoc#C...   object     9      2
# 15             http://www.w3.org/2001/XMLSchema#string     data     9      1
# 16   http://www.w3.org/1999/02/22-rdf-syntax-ns#lan...     data     9     18
# 17              http://www.w3.org/2002/07/owl#Ontology   object     9      1
# 18   http://www.w3.org/2004/02/skos/core#ConceptScheme   object     9      1
# 19   http://www.w3.org/1999/02/22-rdf-syntax-ns#lan...     data     9      9
# 20              http://www.w3.org/2002/07/owl#Ontology   object     9      1
# 21   http://www.w3.org/2004/02/skos/core#ConceptScheme   object     9      1
# 22             http://www.w3.org/2008/05/skos-xl#Label   object     9      9
# 23             http://www.w3.org/2001/XMLSchema#string     data    11     11
# 24             http://www.w3.org/2001/XMLSchema#string     data    11     11
# 25               http://www.w3.org/2001/XMLSchema#date     data    11      2
# 26   http://publications.europa.eu/ontology/euvoc#C...   object    11      1
# 27         http://www.w3.org/2004/02/skos/core#Concept   object    11      1
# 28             http://www.w3.org/2001/XMLSchema#string     data    11     11
# 29               http://www.w3.org/2001/XMLSchema#date     data    11      2
# ..                                                 ...      ...   ...    ...
# 290                    http://xmlns.com/foaf/0.1/Agent   object  1139      4
# 291            http://www.w3.org/2001/XMLSchema#string     data  1139      1
# 292                                                NaN     data   998    228
# 293                     http://purl.org/dc/terms/Agent   object   897     44
# 294        http://www.w3.org/2004/02/skos/core#Concept   object   897     44
# 295              http://www.w3.org/ns/org#Organisation   object   897     44
# 296                    http://xmlns.com/foaf/0.1/Agent   object   897     44
# 297  http://www.w3.org/1999/02/22-rdf-syntax-ns#lan...     data    84     93
# 298  http://www.w3.org/1999/02/22-rdf-syntax-ns#lan...     data   339    449
# 299                                                NaN     data   191    188
# 300  http://www.w3.org/1999/02/22-rdf-syntax-ns#lan...     data    22     20
# 301             http://www.w3.org/2002/07/owl#Ontology   object  1139      1
# 302  http://www.w3.org/2004/02/skos/core#ConceptScheme   object  1139      1
# 303            http://www.w3.org/2001/XMLSchema#string     data     1      1
# 304  http://publications.europa.eu/ontology/datatyp...     data    14     14
# 305  http://publications.europa.eu/ontology/datatyp...     data    33     32
# 306  http://publications.europa.eu/ontology/datatyp...     data    49     50
# 307  http://publications.europa.eu/ontology/datatyp...     data   137    170
# 308  http://publications.europa.eu/resource/authori...     data   138    233
# 309  http://publications.europa.eu/resource/authori...     data    47     50
# 310  http://publications.europa.eu/resource/authori...     data     7      7
# 311  http://publications.europa.eu/resource/authori...     data    10     16
# 312  http://publications.europa.eu/resource/authori...     data    62     62
# 313  http://publications.europa.eu/resource/authori...     data    11     13
# 314  http://publications.europa.eu/resource/authori...     data   333    362
# 315  http://www.w3.org/1999/02/22-rdf-syntax-ns#lan...     data  1139  24160
# 316             http://www.w3.org/2002/07/owl#Ontology   object  1139      1
# 317  http://www.w3.org/2004/02/skos/core#ConceptScheme   object  1139      1
# 318            http://www.w3.org/2008/05/skos-xl#Label   object   563  12284
# 319            http://www.w3.org/2008/05/skos-xl#Label   object  1139  28778
#
#        cnt  min_sp  max_sp     avg_sp
# 0     1053       1       1   1.000000
# 1     1340       1       1   1.000000
# 2     1340       1       1   1.000000
# 3     1340       1       1   1.000000
# 4        9       1       1   1.000000
# 5        9       1       1   1.000000
# 6        9       1       1   1.000000
# 7        9       1       1   1.000000
# 8        9       1       1   1.000000
# 9       18       2       2   2.000000
# 10       9       1       1   1.000000
# 11       9       1       1   1.000000
# 12       4       1       1   1.000000
# 13       4       1       1   1.000000
# 14      18       2       2   2.000000
# 15       9       1       1   1.000000
# 16      18       2       2   2.000000
# 17       9       1       1   1.000000
# 18       9       1       1   1.000000
# 19       9       1       1   1.000000
# 20       9       1       1   1.000000
# 21       9       1       1   1.000000
# 22       9       1       1   1.000000
# 23      11       1       1   1.000000
# 24      11       1       1   1.000000
# 25      11       1       1   1.000000
# 26      11       1       1   1.000000
# 27      11       1       1   1.000000
# 28      11       1       1   1.000000
# 29      11       1       1   1.000000
# ..     ...     ...     ...        ...
# 290   4556       4       4   4.000000
# 291   1139       1       1   1.000000
# 292   1023       1      12   1.179863
# 293    898       1       2   1.002227
# 294    898       1       2   1.002227
# 295    898       1       2   1.002227
# 296    898       1       2   1.002227
# 297     96       1       2   1.250000
# 298    451       1       2   1.496674
# 299    191       1       1   1.000000
# 300     24       1       2   1.166667
# 301   1139       1       1   1.000000
# 302   1139       1       1   1.000000
# 303      1       1       1   1.000000
# 304     14       1       4   1.357143
# 305     33       3      38   8.090909
# 306     51       3      38   6.941176
# 307    170       1      38   4.311765
# 308    240       1      38   8.416667
# 309     50       1      38   6.820000
# 310      7       3      11   8.857143
# 311     16       2       4   3.125000
# 312     62       2      38   5.000000
# 313     13       2      38   8.692308
# 314    362       1      38   2.389503
# 315  24486       1      27  23.199869
# 316   1139       1       1   1.000000
# 317   1139       1       1   1.000000
# 318  12284       1     138  41.132530
# 319  28778       1     216  35.347279
#
# [320 rows x 10 columns]
